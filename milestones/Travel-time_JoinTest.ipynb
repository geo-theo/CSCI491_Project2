# %%
import geopandas as gpd
import pandas as pd

# %%
#transportation stations of Ile-de-France
stations = gpd.read_file("Data/Stations of the Ile-de-France Rail Network.gpkg")

#place holder for time
time = pd.read_csv(
    "Data/Test for Times Join.csv")

# %%
print(stations.columns)
print(time.columns)
# Out:
# Index(['id_gares', 'nom_gares', 'nom_so_gar', 'nom_su_gar', 'id_ref_zdc',
#        'nom_zdc', 'id_ref_zda', 'nom_zda', 'idrefliga', 'idrefligc', 'res_com',
#        'indice_lig', 'mode', 'tertrain', 'terrer', 'termetro', 'tertram',
#        'terval', 'exploitant', 'idf', 'principal', 'x', 'y', 'picto', 'nom_iv',
#        'geometry'],
#       dtype='object')
# Index(['nom_gares', 'time'], dtype='object')

# %%
#merged_stations = stations.merge(time, on="", how="")

# %%
station_time = stations.merge(time, how='left', on='nom_gares')

# %%
station_time
# Out:
#      id_gares                 nom_gares      nom_so_gar nom_su_gar id_ref_zdc  \
# 0         469                     Limay            None       None      65788
# 1         470       L'Isle-Adam-Parmain            None       None      67172
# 2         593         Nogent-le-Perreux            None       None      71609
# 3         783       Santeuil-le-Perchay            None       None      67196
# 4         599              Noisy-le-Sec            None       None      72041
# ...       ...                       ...             ...        ...        ...
# 1229     1170          Georges Millandy            None       None     420463
# 1230      176      Chaville Rive Gauche            None       None      73718
# 1231      746                      Rome            None       None      71408
# 1232       52  Basilique de Saint-Denis  Hôtel de Ville       None      72326
# 1233     1260       Fourqueux - Bel Air            None       None      64566
#
#                           nom_zdc id_ref_zda                   nom_zda  \
# 0                           Limay      43151                     Limay
# 1           L'Isle-Adam - Parmain      47589     L'Isle-Adam - Parmain
# 2             Nogent - Le Perreux      46552       Nogent - Le Perreux
# 3           Santeuil - Le Perchay      47949     Santeuil - Le Perchay
# 4                    Noisy-le-Sec      44201              Noisy-le-Sec
# ...                           ...        ...                       ...
# 1229  Georges Millandy / Clinique      59147          Georges Millandy
# 1230         Chaville Rive Gauche      43108      Chaville Rive Gauche
# 1231                         Rome      44662                      Rome
# 1232     Basilique de Saint-Denis     463329  Basilique de Saint-Denis
# 1233          Fourqueux - Bel Air     480941       Fourqueux - Bel Air
#
#      idrefliga idrefligc  ... terval exploitant idf principal            x  \
# 0       A01852    C01739  ...      0       SNCF   1         0  608349.1982
# 1       A01849    C01737  ...      0       SNCF   1         0  642324.4147
# 2       A01843    C01729  ...      0       SNCF   1         0  662874.6459
# 3       A01852    C01739  ...      0       SNCF   1         0  623305.7394
# 4       A01843    C01729  ...      0       SNCF   1         0  660288.9577
# ...        ...       ...  ...    ...        ...  ..       ...          ...
# 1229    A02149    C01794  ...      0       RATP   1         0  643496.1203
# 1230    A01847    C01736  ...      0       SNCF   1         0  640456.6626
# 1231    A01535    C01372  ...      0       RATP   1         0  650263.2430
# 1232    A01191    C01389  ...      0       RATP   1         0  653172.7894
# 1233    A02373    C02344  ...      0   TRANSKEO   1         0  631812.0584
#
#                  y                                              picto  \
# 0     6.876753e+06  {'thumbnail': True, 'filename': 'train_J.svg',...
# 1     6.890841e+06  {'thumbnail': True, 'filename': 'train_H.svg',...
# 2     6.860040e+06  {'thumbnail': True, 'filename': 'RER_E.svg', '...
# 3     6.892027e+06  {'thumbnail': True, 'filename': 'train_J.svg',...
# 4     6.866430e+06  {'thumbnail': True, 'filename': 'RER_E.svg', '...
# ...            ...                                                ...
# 1229  6.853987e+06  {'thumbnail': True, 'filename': 'tram_T6.svg',...
# 1230  6.856430e+06  {'thumbnail': True, 'filename': 'train_N.svg',...
# 1231  6.864915e+06  {'thumbnail': True, 'filename': 'metro_2.svg',...
# 1232  6.871088e+06  {'thumbnail': True, 'filename': 'tram_T1.svg',...
# 1233  6.866483e+06                                               None
#
#                         nom_iv                  geometry  time
# 0                        Limay  POINT (1.74779 48.98417)   6.0
# 1          L'Isle-Adam-Parmain  POINT (2.21002 49.11478)  30.0
# 2            Nogent-le-Perreux  POINT (2.49419 48.83934)  55.0
# 3          Santeuil-le-Perchay  POINT (1.94933 49.12345)  12.0
# 4                 Noisy-le-Sec  POINT (2.45836 48.89665)  11.0
# ...                        ...                       ...   ...
# 1229          Georges Millandy  POINT (2.23098 48.78350)   NaN
# 1230      Chaville Rive Gauche  POINT (2.18928 48.80520)   NaN
# 1231                      Rome  POINT (2.32180 48.88233)   NaN
# 1232  Basilique de Saint-Denis  POINT (2.36079 48.93806)   NaN
# 1233       Fourqueux - Bel Air  POINT (2.06997 48.89474)   NaN
#
# [1234 rows x 27 columns]
